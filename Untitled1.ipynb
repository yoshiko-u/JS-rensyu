# %% [markdown]
# <a href="https://colab.research.google.com/github/yoshiko-u/Py_rensyu/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup


html = requests.get("https://www.stallman.org").text

soup = BeautifulSoup(html,"html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="rss/rss.xml" rel="alternate" title="RMS RSS" type="application/rss+xml"/>
# <title>Richard Stallman's Personal Page</title>
# <link href="/common/stallman.css" rel="stylesheet" type="text/css"/>
# <link href="https://stallman.org/rms.png" rel="shortcut icon" type="image/x-icon"/>
# <link href="rms.png" rel="icon"/>
# </head>
# <body style="min-width:678px;">
# <h3 class="c1">
#       Richard Stallman's Personal Site
#     </h3>
# <div style="text-align:center; font-size:16pt; margin:50px;">I
# continue to be the Chief GNUisance of the GNU Project.<br/>
# I do not intend to stop any time soon.</div>
# <center>
# <!--    If you participate in the commercial ritual of end-of-the-year
#     presents, please avoid the digital products that would mistreat
#     the people you give them to.
#     <h3>
# ...

# %%
import requests
from bs4 import BeautifulSoup

html = requests.get("https://minkabu.jp/stock/7203").text


soup = BeautifulSoup(html,"html.parser")
els = soup.find("div",{"class":"stock_price"})
print(els.text.strip())
# Out:
# 6,915.0
# 円

# %%
# !pip3 install gspread

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials


gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
sh = gc.create('scrapel')
worksheet = gc.open('scrapel').sheet1

# %%
import requests
from bs4 import  BeautifulSoup

url = "https://gigazine.net/"

for i in range(5):

  html = requests.get(url).text

  soup = BeautifulSoup(html,"html.parser")

  next = soup.find("div",{"id":"nextpage"})

  url = next.find("a").attrs["href"]

  cards = soup.find_all("div",{"class":"card"})

  for card in cards:

    title = card.find("h2").text.strip()

    href = card.find("a").attrs["href"]

    worksheet.append_row([
                          title,
                          href,
    ])
